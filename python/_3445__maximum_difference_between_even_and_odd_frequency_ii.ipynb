# %%
a = 8
b = 1
res = (a&1)<<1 | (b&1)
print(res)
# convert res to binary
res_bin = bin(res)[2:]
print(res_bin)
# Out:
# 1
# 1

# %%
class Solution:
    def maxDifference(self, s: str, k: int) -> int:
        def status(a, b):   
            return (a & 1) << 1 | (b & 1)  # tạo bitmask từ parity (even/odd) của a và b

        ans = float('-inf')
        n = len(s)

        for ca in '01234':
            for cb in '01234':
                if ca == cb:
                    continue
                print(f"\n=== 🔍 Xét cặp (a='{ca}', b='{cb}') ===")
                
                best = [float('inf')] * 4  # best[bitmask] = min(prev_a - prev_b)
                cnt_a = cnt_b = prev_a = prev_b = 0
                left = -1

                for right in range(n):
                    if s[right] == ca:
                        cnt_a += 1
                    if s[right] == cb:
                        cnt_b += 1
                    
                    # Debug khi mở rộng cửa sổ
                    print(f"[→] right={right}, s[right]={s[right]}, cnt_a={cnt_a}, cnt_b={cnt_b}, left={left}")

                    # Rút gọn cửa sổ nếu đủ dài và đủ b
                    while right - left >= k and (cnt_b - prev_b) >= 2:
                        st = status(prev_a, prev_b)
                        old_best = best[st]
                        best[st] = min(best[st], prev_a - prev_b)
                        if best[st] != old_best:
                            print(f"    💾 best[{st}] cập nhật: {best[st]} (parity a={prev_a%2}, b={prev_b%2})")

                        left += 1
                        if s[left] == ca:
                            prev_a += 1
                        if s[left] == cb:
                            prev_b += 1
                        print(f"    🔁 Shrink left={left}, prev_a={prev_a}, prev_b={prev_b}")

                    # Cập nhật kết quả nếu tìm thấy trạng thái đối xứng
                    st2 = status(cnt_a, cnt_b)
                    target = st2 ^ 2  # đối xứng bit 1 của `a`

                    if best[target] < float('inf'):
                        current_score = cnt_a - cnt_b - best[target]
                        if current_score > ans:
                            print(f"✅ Update ans: {current_score} (cnt_a={cnt_a}, cnt_b={cnt_b}, best[{target}]={best[target]})")
                        ans = max(ans, current_score)

        print("\n🎯 Kết quả cuối cùng:")
        return ans if ans != float('-inf') else -1


# =============================
# 🚀 Test cases
# =============================
sol = Solution()

test_cases = [
    ("12042103", 3),
]

for i, (s, k) in enumerate(test_cases, 1):
    print(f"\n🧪 Test case {i}: s = '{s}', k = {k}'")
    result = sol.maxDifference(s, k)
    print(f"➡️  Output = {result}")
# Out:
# 🧪 Test case 1: s = '12042103', k = 3'
#
# === 🔍 Xét cặp (a='0', b='1') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=1
# ✅ Update ans: -1 (cnt_a=1, cnt_b=2, best[0]=0)
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=0
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=0
#
# === 🔍 Xét cặp (a='0', b='2') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=0, prev_b=1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=2, left=1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=1
#
# === 🔍 Xét cặp (a='0', b='3') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=0, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=0, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='0', b='4') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=1, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='1', b='0') ===
# [→] right=0, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=1, prev_b=0
#     💾 best[2] cập nhật: 1 (parity a=1, b=0)
#     🔁 Shrink left=1, prev_a=1, prev_b=0
#     🔁 Shrink left=2, prev_a=1, prev_b=1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=2
#
# === 🔍 Xét cặp (a='1', b='2') ===
# [→] right=0, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=1, prev_b=0
#     💾 best[2] cập nhật: 1 (parity a=1, b=0)
#     🔁 Shrink left=1, prev_a=1, prev_b=1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=2, left=1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=1
#
# === 🔍 Xét cặp (a='1', b='3') ===
# [→] right=0, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=0, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=0, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=0, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='1', b='4') ===
# [→] right=0, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=1, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='2', b='0') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=2, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=1, prev_b=0
#     💾 best[2] cập nhật: 1 (parity a=1, b=0)
#     🔁 Shrink left=2, prev_a=1, prev_b=1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=2
#
# === 🔍 Xét cặp (a='2', b='1') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=2, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=2, left=0
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=2, left=0
#
# === 🔍 Xét cặp (a='2', b='3') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=0, left=-1
# [→] right=4, s[right]=2, cnt_a=2, cnt_b=0, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=0, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=0, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='2', b='4') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=2, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=2, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=2, cnt_b=1, left=-1
# [→] right=7, s[right]=3, cnt_a=2, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='3', b='0') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=0, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=0, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=0, prev_b=0
#     🔁 Shrink left=2, prev_a=0, prev_b=1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=2
#
# === 🔍 Xét cặp (a='3', b='1') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=0, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=0, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=1
# [→] right=6, s[right]=0, cnt_a=0, cnt_b=2, left=0
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=0
#
# === 🔍 Xét cặp (a='3', b='2') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=0, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=0, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=0, prev_b=1
# [→] right=5, s[right]=1, cnt_a=0, cnt_b=2, left=1
# [→] right=6, s[right]=0, cnt_a=0, cnt_b=2, left=1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=1
#
# === 🔍 Xét cặp (a='3', b='4') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=0, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=1, left=-1
#
# === 🔍 Xét cặp (a='4', b='0') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=1, left=-1
# [→] right=6, s[right]=0, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=0, prev_b=0
#     🔁 Shrink left=2, prev_a=0, prev_b=1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=2
#
# === 🔍 Xét cặp (a='4', b='1') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=1, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=1, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=1
# [→] right=6, s[right]=0, cnt_a=1, cnt_b=2, left=0
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=0
#
# === 🔍 Xét cặp (a='4', b='2') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=1, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=1, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=1, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=2, left=-1
#     💾 best[0] cập nhật: 0 (parity a=0, b=0)
#     🔁 Shrink left=0, prev_a=0, prev_b=0
#     🔁 Shrink left=1, prev_a=0, prev_b=1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=2, left=1
# [→] right=6, s[right]=0, cnt_a=1, cnt_b=2, left=1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=2, left=1
#
# === 🔍 Xét cặp (a='4', b='3') ===
# [→] right=0, s[right]=1, cnt_a=0, cnt_b=0, left=-1
# [→] right=1, s[right]=2, cnt_a=0, cnt_b=0, left=-1
# [→] right=2, s[right]=0, cnt_a=0, cnt_b=0, left=-1
# [→] right=3, s[right]=4, cnt_a=1, cnt_b=0, left=-1
# [→] right=4, s[right]=2, cnt_a=1, cnt_b=0, left=-1
# [→] right=5, s[right]=1, cnt_a=1, cnt_b=0, left=-1
# [→] right=6, s[right]=0, cnt_a=1, cnt_b=0, left=-1
# [→] right=7, s[right]=3, cnt_a=1, cnt_b=1, left=-1
#
# 🎯 Kết quả cuối cùng:
# ➡️  Output = -1
